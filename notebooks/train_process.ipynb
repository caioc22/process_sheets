# %%
import pandas as pd
import numpy as np
from scipy import stats
import re, random, sys, pickle
                                            # tfidf          # bad-of-words
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, f1_score

import nltk
from nltk.corpus import wordnet

sys.path.insert(0,'..')
from fields import *

# %%
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
sheet = pd.read_excel('../sheets/DRE_07.2022.xlsx')

# %% [markdown]
# # Model training
# Sheet theme recognizer

# %% [markdown]
# ## Generate data

# %%
def find_synonyms(words, qty):

    new_words = []
    for word in words:
        if len(word.split(' ')) > 1:
            word = word.split(' ')[0]

        synonyms=[];
        for syn in wordnet.synsets(word, lang='por'):
            for lemma in syn.lemmas(lang='por'):
                synonyms.append(lemma.name())

        if len(synonyms) > 0:
            new_words.append(np.random.choice(synonyms, size=qty)[0])
        else:
            new_words.append(word)

    return new_words

def vectorize_csv(df, vectorizer, only_strings=False):
    
    if isinstance(df, np.ndarray): df = pd.DataFrame(df)

    if only_strings is True:
        is_word = r'[A-Za-z\s]+'
        words = []
        for column in df.select_dtypes(include=['object']):
            for cell in df[column]:
                if isinstance(cell, str):
                    matches = re.findall(is_word, cell)
                    words.extend(matches)
        text = ' '.join(words)
    else:
        flatten = df.astype(str).values.flatten()
        text = ' '.join(flatten)
    # Fit the vectorizer with a 1-D array, only if it has not been fitted before
    if not hasattr(vectorizer, 'vocabulary_'):
        vectorizer.fit([text])
    # Transforming text placed in a 2-D array using the transform method
    vector=[]
    display(text)
    # vectorize many
    if len(df.columns) == 1:
        for doc in df.iloc[:, 0]:
            vec = vectorizer.transform([doc]).toarray()
            vector.extend(vec)
    # vectorize only one document
    else:
        vec = vectorizer.transform([text]).toarray()
        vector.extend(vec)
    vector=np.array(vector)

    if not hasattr(vectorizer, 'vocabulary_'):
        return vector, vectorizer
    return vector


def adjust_vectors(vectors, max_=None):

    adjusted_vectors = []
    if max_ is None:
        lengths = [len(vec) for vec in vectors]
        max_ = np.max(lengths)

    for vec in vectors:
        fill = max_ - len(vec)
        if fill > 0:
            mode = stats.mode(vec, keepdims=True)[0][0]
            fill = np.full(fill, mode)
            vec = np.concatenate([vec, fill], axis=0)
            adjusted_vectors.append(vec)
        else:
            adjusted_vectors.append(vec)

    return np.array(adjusted_vectors)


def generate_accounting_data(qty, type_, how, vectorizer=None):
    if type_ in ["dre", 1]: fields, label = dre, 1
    if type_ in ["balancete", 2]: fields, label = balancete, 2

    data = []
    size = int( len(list(fields.keys())) * random.uniform(0.6, 1) )
    for i in range(0, qty):
        dfs = []; text = []
        
        random_fields = np.random.choice(list(fields.keys()), size)
        for f in random_fields:
            words = [f, *fields[f]]
            words = find_synonyms(words, 1)

            if how=="text":
                text.extend(words)

            elif how=="sheet":
                values = [round(val, 2) for val in np.random.uniform(1e5, 2e5, size=len(words))]
                df = pd.DataFrame(data=[words, values]).T
                dfs.append(df)
        
        if how=="text":
            data.append(' '.join(text))

        elif how=="sheet":
            dfs = pd.concat(dfs)
    
            # data.append(dfs)
    X = np.array(data); y = np.full(len(data), label)

    if vectorizer:
        print(vectorizer)
        # vectorize words by row
        # vectors = []
        # for row in X:
        X = vectorize_csv(X, vectorizer, True)
            # vectors.append(vector)
        # adjusting shape
        # display(vectors.shape, vectors)
        # adjusted_vectors = adjust_vectors(vectors)
        return X, y, vectorizer
    
    return X, y

# X_, y_ = generate_accounting_data(10, 'dre', 'text', TfidfVectorizer())
X=[]; y=[]; vectorizers = {}
for doc in ['dre', 'balancete']:
    X_, y_, vectorizer = generate_accounting_data(50, doc, 'text', CountVectorizer())
    vectorizers[doc] = vectorizer
    X.extend(X_); y.extend(y_)

X=adjust_vectors(X); y=np.array(y)
X.shape, y.shape
# Out:
# CountVectorizer()
# 'conclus o Receitas custos despesas resultado resultado Dedu es Devolu es imposto EBITDA benef cio deprecia o amortiza o custo Mat ria prima for a de trabalho custos deprecia o continua o EBITDA vantagem deprecia o Amortiza o resultado conseq ncia rendimento Receitas despesas EBITDA handicap deprecia o amortiza o EBITDA handicap deprecia o Amortiza o Dedu es Devolu es imposto resultado Receitas pre o despesas fim efeitos fim juros Receitas despesas despesas Comerciais Administrativas Financeiras Dedu es Devolu es taxa Dedu es Devolu es colectas despesas Comerciais Administrativas Financeiras EBITDA benef cio deprecia o amortiza o despesas Comerciais Administrativas Financeiras Dedu es Devolu es taxa receita Vendas servi os Outros provento Vendas servi os Outros conseq ncia juro Receitas despesas Dedu es Devolu es colectas Dedu es Devolu es tributo fim Receitas pre o despesas continua o conseq ncia resultado Receitas despesas efeitos conseq ncia resultado conclus o Dedu es Devolu es impostos custo Mat ria prima for a de trabalho custo deprecia o provis o imposto contribui o EBITDA lucro deprecia o amortiza o gastos Mat ria prima m o de obra pre os deprecia o EBITDA utilidade deprecia o amortiza o despesas Comerciais Administrativas Financeiras Receita Vendas servi os Outros prescri o Vendas servi os Outros resultado Receitas custos despesas resultado conclus o despesas Comerciais Administrativas Financeiras resultado interesses Receitas despesas efeitos lucro resultado Receitas custo despesas resultado fim placar Receitas despesas resultado Receitas custo despesas fim resultado EBITDA valor deprecia o Amortiza o provis o impostos donativo renda Vendas servi os Outros fim Receitas custo despesas resultado chegada lucro resultado conseq ncia renda Vendas servi os Outros impostos PIS COFINS ICMS IPI provis o impostos contribui o estip ndio Mat ria prima trabalho custo deprecia o fim Receitas custo despesas resultado fim resultado Receitas despesas custo Mat ria prima m o de obra custos deprecia o vantagem despesa mat rias primas m o de obra custo deprecia o fim Receitas custo despesas fim resultado tributo PIS COFINS ICMS IPI EBITDA operacionalidade deprecia o amortiza o remunera es Mat ria Prima trabalho pre o deprecia o provis o imposto donativo benef cio conseq ncia rendimento Receitas despesas conclus o Receitas despesas conseq ncia interesses Receitas despesas fim resultado resultado Dedu es Devolu es taxa resultado Receitas pre os despesas placar resultado resultado Receitas custo despesas chegada placar despesas Comerciais Administrativas Financeiras conclus o Receitas despesas Renda Vendas servi os Outros provis o taxa contribui o placar rendimento Receitas despesas renda Vendas servi os Outros resultado juros Receitas despesas Dedu es Devolu es colectas resultado despesas Comerciais Administrativas Financeiras imposto PIS COFINS ICMS IPI resultado Receitas gastos despesas resposta resultado resultado Receitas custo despesas resultado resultado provis o taxa contribui o provis o impostos donativo ingresso Vendas servi os Outros resultado provis o imposto donativo resultado pre os Mat ria prima for a de trabalho pre o deprecia o resposta Receitas despesas benef cio resultado renda Vendas servi os Outros EBITDA lucro deprecia o amortiza o custo mat ria prima for a de trabalho custo deprecia o EBITDA utilidade deprecia o Amortiza o Dedu es Devolu es imposto rendimento Vendas servi os Outros EBITDA operacionalidade deprecia o amortiza o despesas Comerciais Administrativas Financeiras despesas Comerciais Administrativas Financeiras provis o taxa contribui o impostos PIS COFINS ICMS IPI pre o Mat ria prima homens custos deprecia o despesas Comerciais Administrativas Financeiras resultado juro Receitas despesas provis o tributo doa o EBITDA lucro deprecia o Amortiza o EBITDA handicap deprecia o amortiza o resultado Receitas custos despesas conclus o placar despesas Comerciais Administrativas Financeiras placar juros Receitas desp ...
# CountVectorizer()
# 'ativo Circulante realiz vel Investimentos Imobilizado Intang vel ativo Circulante que se pode alcan ar Investimentos Imobilizado Intang vel despesas custos custos despesas r pido Circulante que se pode alcan ar Investimentos Imobilizado Intang vel ativo Circulante conquist vel Investimentos Imobilizado Intang vel Receitas Vendas Vendas Outras despesas custo custo despesas Receitas Vendas Vendas Outras bem capital reservas Ajustes reservas ecologia responsabilidade Circulante Exig vel Receitas Vendas Vendas Outras despesas custos custo despesas l pido Circulante que se pode conquistar Investimentos Imobilizado Intang vel obriga o Circulante Exig vel Receitas Vendas Vendas Outras despesas pre o custo despesas Patrim nio Capital reservas ecologia  Ajustes reservas ecologia  passivo Circulante Exig vel patrim nio fundo reservas Ajustes reservas Receitas Vendas Vendas Outras heran a Capital reserva Ajustes reserva d vida Circulante Exig vel obriga o Circulante Exig vel despesas custo pre o despesas despesas pre os pre o despesas Receitas Vendas Vendas Outras Receitas Vendas Vendas Outras endividamento Circulante Exig vel Receitas Vendas Vendas Outras passivo Circulante Exig vel despesas custos custos despesas Receitas Vendas Vendas Outras Receitas Vendas Vendas Outras activos Circulante conquist vel Investimentos Imobilizado Intang vel recursos Circulante capaz de ser feito Investimentos Imobilizado Intang vel Receitas Vendas Vendas Outras r pido Circulante que se pode conquistar Investimentos Imobilizado Intang vel responsabilidade Circulante Exig vel ativo Circulante realiz vel Investimentos Imobilizado Intang vel obriga o Circulante Exig vel despesas pre o custo despesas vozactiva Circulante que se pode alcan ar Investimentos Imobilizado Intang vel endividamento Circulante Exig vel Receitas Vendas Vendas Outras ativo Circulante conquist vel Investimentos Imobilizado Intang vel Receitas Vendas Vendas Outras agencioso Circulante conquist vel Investimentos Imobilizado Intang vel passivo Circulante Exig vel passivo Circulante Exig vel Receitas Vendas Vendas Outras bens de raiz fundo reserva Ajustes reservas despesas gastos gastos despesas patrim nio Capital reservas ecologia  Ajustes reserva pac fico Circulante Exig vel legado fundo reservas Ajustes reservas pac fico Circulante Exig vel Receitas Vendas Vendas Outras obriga o Circulante Exig vel vozactiva Circulante que se pode conquistar Investimentos Imobilizado Intang vel pac fico Circulante Exig vel ativo Circulante realiz vel Investimentos Imobilizado Intang vel d vida Circulante Exig vel fazenda capital reserva Ajustes reserva ativo Circulante conquist vel Investimentos Imobilizado Intang vel bens de raiz capital reservas Ajustes reservas ecologia  endividamento Circulante Exig vel despesas gastos pre os despesas lesto Circulante capaz de ser feito Investimentos Imobilizado Intang vel Receitas Vendas Vendas Outras bens de raiz Capital reservas ecologia  Ajustes reservas ecologia  despesas gastos custos despesas heran a capital reservas ecologia  Ajustes reservas ecologia Receitas Vendas Vendas Outras patrim nio Capital reserva Ajustes reservas ecologia  despesas custo custos despesas Patrim nio capital reserva Ajustes reservas heran a Capital reservas Ajustes reservas ecologia  despesas custos custos despesas r pido Circulante que se pode alcan ar Investimentos Imobilizado Intang vel passivo Circulante Exig vel l pido Circulante conquist vel Investimentos Imobilizado Intang vel recursos Circulante realiz vel Investimentos Imobilizado Intang vel obriga o Circulante Exig vel responsabilidade Circulante Exig vel bens de raiz fundo reservas ecologia  Ajustes reserva propriedade fundos reserva Ajustes reservas ecologia  despesas pre o pre os despesas Patrim nio capital reservas ecologia  Ajustes reservas ecologia  vozactiva Circulante conquist vel Investimentos Imobilizado Intang vel vozactiva Circulante que se pode conquistar Investimentos Imobilizado Intang vel d vida Circulante  ...
# ((100, 83), (100,))

# %% [markdown]
# ## Training model

# %%
svm = SVC(kernel='linear', probability=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape)
svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

print( classification_report(y_test,y_pred) )
# Out:
# (80, 83)
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %% [markdown]
# ## Real testing

# %%
# hasattr(CountVectorizer(), 'vocabulary_'), hasattr(vectorizers['dre'], 'vocabulary_')
def clean_sheet(sheet):
    #clean nan cols and rows
    sheet = sheet.dropna(how='all', axis=1).dropna(how='all', axis=0)
    #most frequent row nans pattern
    mode = stats.mode(sheet.isna().sum(axis=1), keepdims=True)[0][0]
    #assuming this as where to scrap data
    data = pd.concat([row for _, row in sheet.iterrows() if row.isna().sum() == mode], axis=1).T

    valid_data = pd.concat(
        [
            col for _, col in data.items() 
            if col.isna().sum() < len(col)*0.1
        ], 
    axis=1).reset_index()

    return valid_data

# %%
dre_test = pd.read_excel('../sheets/DRE_07.2022.xlsx', index_col=[0])
valid_data = clean_sheet(dre_test)
vector = vectorize_csv(valid_data, vectorizers['dre'], only_strings=True)
doc_type = svm.predict(vector)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 22
#      20 dre_test = pd.read_excel('../sheets/DRE_07.2022.xlsx', index_col=[0])
#      21 valid_data = clean_sheet(dre_test)
# ---> 22 vector = vectorize_csv(valid_data, vectorizers['dre'], only_strings=True)
#      23 doc_type = svm.predict(vector)
#
# NameError: name 'vectorize_csv' is not defined

# %%
balan_test = pd.read_excel('../sheets/Cópia BALANCETE_31.07.2022.xlsx', index_col=[0])
valid_data = clean_sheet(balan_test)
vector = vectorize_csv(valid_data, vectorizers['dre'], only_strings=True)
svm.predict(vector)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 3
#       1 balan_test = pd.read_excel('../sheets/Cópia BALANCETE_31.07.2022.xlsx', index_col=[0])
#       2 valid_data = clean_sheet(balan_test)
# ----> 3 vector = vectorize_csv(valid_data, vectorizers['dre'], only_strings=True)
#       4 svm.predict(vector)
#
# KeyError: 'dre'

# %%
pickle.dump(svm, open('../models/svm_1.pkl', 'wb'))

# %% [markdown]
# # Scraping

# %%
dre_test = pd.read_excel('../sheets/DRE_07.2022.xlsx', index_col=[0])
balan_test = pd.read_excel('../sheets/Cópia BALANCETE_31.07.2022.xlsx')

# %%
balan_test.head(10)
clean_sheet(balan_test)
# Out:
#      index           Unnamed: 0 Unnamed: 2  \
# 0        5       Conta Contábil    Cod. R.
# 1        7  1.0.00.00.00.000000          1
# 2        9  1.1.00.00.00.000000         11
# 3       11  1.1.01.00.00.000000         12
# 4       13  1.1.01.01.00.000000         13
# ..     ...                  ...        ...
# 354    446  5.1.90.01.00.000000      51061
# 355    447  5.1.90.01.05.000000     529559
# 356    448  5.1.90.01.06.000000     529562
# 357    449  5.1.90.01.00.000002       5922
# 358    450  5.1.90.01.19.000000     539509
#
#                                Unnamed: 4  Unnamed: 7   Unnamed: 9  \
# 0                                     NaN         NaN       Débito
# 1                               A T I V O  1899516.77  15189090.34
# 2                        ATIVO CIRCULANTE  1725485.06  15180120.94
# 3            CAIXA E EQUIVALENTE DE CAIXA   384989.03   4965261.93
# 4                             CAIXA GERAL       802.4     17445.66
# ..                                    ...         ...          ...
# 354          OUTRAS RECEITAS OPERACIONAIS           0            0
# 355                ICMS S/OUTRAS ENTRADAS           0            0
# 356                 IPI S/OUTRAS ENTRADAS           0            0
# 357           RECUPERACAO CUSTOS/DESPESAS           0            0
# 358  RESSARCIMENTO EXCLUSAO BC PIS/COFINS           0            0
#
#      Unnamed: 11 Unnamed: 13
# 0        Crédito    S. Atual
# 1    14995080.36  2093526.75
# 2     14973085.5   1932520.5
# 3      5273272.6    76978.36
# 4       16513.91     1734.15
# ..           ...         ...
# 354    102566.96  -102566.96
# 355          288        -288
# 356          576        -576
# 357      4272.52    -4272.52
# 358     97430.44   -97430.44
#
# [359 rows x 8 columns]

# %%
def data_scraping(sheet, doc_type):
    
    valid_data = clean_sheet(sheet).astype(str)
    
    # EXTRACT ACCOUNTING FIELDS
    fields = []
    strings = valid_data.applymap(lambda x: re.findall(r'\D+', x)) #[^0-9\.,]
    for _, col in strings.items():
        # check valid columns
        if col.tolist().count([]) < len(col):
            for row in col:
                if len(row) > 0:
                    fields.extend(row)

    # EXTRACT FIELDS VALUE
    all_values = []
    numbers = valid_data.applymap(lambda x: re.findall(r'\d+', x))
    for _, col in numbers.items():
        values = []
        # check valid columns
        if col.tolist().count([]) < len(col):
            for row in col:
                if len(row) > 1:
                    try:
                        decimal = float( int(row[-1])/100 )
                        integer = int(''.join(row[:-1]))
                        values.append(integer + decimal)
                    except:
                        pass
                else:
                    values.append(np.nan)
        if len(values) > 0:    
            all_values.append(values)

    if doc_type == 1:
        data = pd.DataFrame(data=[fields, *all_values]).T
    
    elif doc_type == 2:
        data = pd.DataFrame(data=[fields, *all_values]).T

    return data.dropna(how='all', axis=1)

# data_scraping(dre_test, 1).head(50)
data_scraping(balan_test, 2).head(50)
# Out:
#                  0            2    4           5            6            7  \
# 0   Conta Contábil          NaN  NaN         NaN          NaN          NaN
# 1                .   10000000.0  NaN  1899516.77  15189090.34  14995080.36
# 2                .   11000000.0  NaN  1725485.06  15180120.94  14973085.05
# 3                .   11010000.0  NaN   384989.03   4965261.93   5273272.06
# 4                .   11010100.0  NaN      802.04     17445.66     16513.91
# 5                .  11010101.01  NaN      802.04     17445.66     16513.91
# 6                .   11010200.0  NaN   293350.89   4584831.05   4859522.32
# 7                .   11010201.0  NaN   293350.89   4584831.05   4859522.32
# 8                .  11010201.04  NaN   293350.89   4107843.71   4382534.98
# 9                .  11010201.01  NaN         NaN    476987.34    476987.34
# 10               .   11010300.0  NaN    90835.74    362985.22    397236.37
# 11               .   11010301.0  NaN    90835.74    362985.22    397236.37
# 12               .   11010301.7  NaN         NaN    243088.58    302735.43
# 13               .  11011784.04  NaN       32.82         2.08        34.09
# 14               .  11011784.05  NaN      802.92      7088.15      7891.07
# 15               .  11010301.01  NaN         NaN    112806.41     86574.97
# 16               .   11020000.0  NaN   318953.41  10007697.53   9456993.35
# 17               .   11020200.0  NaN   318953.41  10007697.53   9456993.35
# 18               .   11020201.0  NaN   318953.41  10007697.53   9456993.35
# 19               .  11020201.01  NaN   318953.41   4547580.99   3996876.81
# 20               .  11020201.03  NaN         NaN   2730058.27   2730058.27
# 21               .  11020201.02  NaN         NaN   2730058.27   2730058.27
# 22               .   11030000.0  NaN    61431.67    207161.48    242819.55
# 23               .   11030300.0  NaN         NaN          NaN     37633.47
# 24               .   11030301.0  NaN         NaN          NaN     37633.47
# 25               .  11030301.03  NaN         NaN      6173.06      5761.53
# 26               .  11030301.05  NaN         NaN      3011.71      3011.71
# 27               .  11030301.01  NaN         NaN     28860.23     28860.23
# 28               .   11030400.0  NaN    35453.32     30808.41     49392.69
# 29               .   11030401.0  NaN    35453.32      9494.92     39451.87
# 30               .   11031285.9  NaN    31077.07      8411.92     33993.25
# 31               .  11034429.14  NaN     2166.33          NaN      3249.33
# 32               .   11033902.9  NaN      521.29          NaN       521.29
# 33               .  11034740.45  NaN         NaN          NaN          NaN
# 34               .   11030402.0  NaN         NaN     21313.49      9940.82
# 35               .  11030402.33  NaN         NaN     21313.49      9940.82
# 36               .   11030700.0  NaN    18143.01    138308.07    148124.95
# 37               .   11030701.0  NaN    18143.01    138308.07    148124.95
# 38               .  11030701.01  NaN    14479.78     38148.95     52628.73
# 39               .  11030701.28  NaN     3663.23     97430.44     95496.22
# 40               .  11030701.09  NaN         NaN      2728.68          NaN
# 41               .   11030900.0  NaN     7835.34          NaN      7668.44
# 42               .   11030901.0  NaN     7835.34          NaN      7668.44
# 43               .  11030901.01  NaN     7835.34          NaN      7668.44
# 44               .   11040000.0  NaN   960110.95          NaN          NaN
# 45               .   11040100.0  NaN   960110.95          NaN          NaN
# 46               .   11040101.0  NaN   960110.95          NaN          NaN
# 47               .  11040101.01  NaN   960110.95          NaN          NaN
# 48               .   12000000.0  NaN   174031.71      8969.04     21994.86
# 49               .   12030000.0  NaN   174031.71      8969.04     21994.86
#
#              8
# 0          NaN
# 1   2093526.75
# 2   1932520.05
# 3     76978.36
# 4      1734.15
# 5      1734.15
# 6     18659.62
# 7     18659.62
# 8     18659.62
# 9          NaN
# 10    56584.59
# 11    56584.59
# 12    30353.15
# 13         NaN
# 14         NaN
# 15    26231.44
# 16   869657.59
# 17   869657.59
# 18   869657.59
# 19   869657.59
# 20         NaN
# 21         NaN
# 22    25773.06
# 23      411.53
# 24      411.53
# 25      411.53
# 26         NaN
# 27         NaN
# 28    16869.04
# 29     5496.37
# 30     5496.37
# 31         NaN
# 32         NaN
# 33         NaN
# 34    11372.67
# 35    11372.67
# 36     8326.13
# 37     8326.13
# 38         NaN
# 39     5597.45
# 40     2728.68
# 41      166.09
# 42      166.09
# 43      166.09
# 44   960110.95
# 45   960110.95
# 46   960110.95
# 47   960110.95
# 48   161006.25
# 49   161006.25
